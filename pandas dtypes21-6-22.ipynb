# %%
import pandas as pd
df=pd.read_csv("1000records.csv")
df
# Out:
#      Age Attrition     BusinessTravel  DailyRate              Department  \
# 0     31        No  Travel_Frequently        836                 Support
# 1     43       Yes         Non-Travel       1071         Human Resources
# 2     25       Yes         Non-Travel       1374  Research & Development
# 3     29        No  Travel_Frequently       1415                 Support
# 4     20       Yes      Travel_Rarely       1076         Human Resources
# ..   ...       ...                ...        ...                     ...
# 995   49        No         Non-Travel       1465                 Support
# 996   24       Yes  Travel_Frequently        387                   Sales
# 997   45       Yes      Travel_Rarely       1304                Software
# 998   39        No         Non-Travel        217                Hardware
# 999   19       Yes  Travel_Frequently       1447                Hardware
#
#      DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1000 non-null   int64
#  1   Attrition                 1000 non-null   object
#  2   BusinessTravel            1000 non-null   object
#  3   DailyRate                 1000 non-null   int64
#  4   Department                1000 non-null   object
#  5   DistanceFromHome          1000 non-null   int64
#  6   Education                 1000 non-null   int64
#  7   EducationField            1000 non-null   object
#  8   EmployeeCount             1000 non-null   int64
#  9   EmployeeNumber            1000 non-null   int64
#  10  EnvironmentSatisfaction   1000 non-null   int64
#  11  Gender                    1000 non-null   object
#  12  HourlyRate                1000 non-null   int64
#  13  JobInvolvement            1000 non-null   int64
# ...

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
dfn=df.convert_dtypes()
dfn
# Out:
#      Age Attrition     BusinessTravel  DailyRate              Department  \
# 0     31        No  Travel_Frequently        836                 Support
# 1     43       Yes         Non-Travel       1071         Human Resources
# 2     25       Yes         Non-Travel       1374  Research & Development
# 3     29        No  Travel_Frequently       1415                 Support
# 4     20       Yes      Travel_Rarely       1076         Human Resources
# ..   ...       ...                ...        ...                     ...
# 995   49        No         Non-Travel       1465                 Support
# 996   24       Yes  Travel_Frequently        387                   Sales
# 997   45       Yes      Travel_Rarely       1304                Software
# 998   39        No         Non-Travel        217                Hardware
# 999   19       Yes  Travel_Frequently       1447                Hardware
#
#      DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
dfn.dtypes
# Out:
# Age                          Int64
# Attrition                   string
# BusinessTravel              string
# DailyRate                    Int64
# Department                  string
# DistanceFromHome             Int64
# Education                    Int64
# EducationField              string
# EmployeeCount                Int64
# EmployeeNumber               Int64
# EnvironmentSatisfaction      Int64
# Gender                      string
# HourlyRate                   Int64
# JobInvolvement               Int64
# JobLevel                     Int64
# JobRole                     string
# JobSatisfaction              Int64
# MaritalStatus               string
# MonthlyIncome                Int64
# MonthlyRate                  Int64
# NumCompaniesWorked           Int64
# Over18                      string
# OverTime                    string
# PercentSalaryHike            Int64
# PerformanceRating            Int64
# RelationshipSatisfaction     Int64
# StandardHours                Int64
# ...

# %%
df.isnull()
# Out:
#        Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0    False      False           False      False       False
# 1    False      False           False      False       False
# 2    False      False           False      False       False
# 3    False      False           False      False       False
# 4    False      False           False      False       False
# ..     ...        ...             ...        ...         ...
# 995  False      False           False      False       False
# 996  False      False           False      False       False
# 997  False      False           False      False       False
# 998  False      False           False      False       False
# 999  False      False           False      False       False
#
#      DistanceFromHome  Education  EducationField  EmployeeCount  \
# 0               False      False           False          False
# 1               False      False           False          False
# ...

# %%
import pandas as pd
a=pd.read_csv("student.csv")
a
# Out:
#     S.NO name  marks
# 0      1    a     10
# 1      2    b      9
# 2      3    c      8
# 3      4    d      8
# 4      5    e      9
# 5      6    f     10
# 6      7    g      7
# 7      8    h      6
# 8      9    i     10
# 9     10    j      7
# 10    11    k      8

# %%
a.head="None"
a
# Out:
#     S.NO name  marks
# 0      1    a     10
# 1      2    b      9
# 2      3    c      8
# 3      4    d      8
# 4      5    e      9
# 5      6    f     10
# 6      7    g      7
# 7      8    h      6
# 8      9    i     10
# 9     10    j      7
# 10    11    k      8

# %%
a.dtypes
# Out:
# S.NO      int64
# name     object
# marks     int64
# dtype: object

# %%
b=a.convert_dtypes()
b
# Out:
#     S.NO name  marks
# 0      1    a     10
# 1      2    b      9
# 2      3    c      8
# 3      4    d      8
# 4      5    e      9
# 5      6    f     10
# 6      7    g      7
# 7      8    h      6
# 8      9    i     10
# 9     10    j      7
# 10    11    k      8

# %%
b.dtypes
# Out:
# S.NO      Int64
# name     string
# marks     Int64
# dtype: object

# %%
c=pd.read_csv("student.csv",header=None)
c
# Out:
#        0     1      2
# 0   S.NO  name  marks
# 1      1     a     10
# 2      2     b      9
# 3      3     c      8
# 4      4     d      8
# 5      5     e      9
# 6      6     f     10
# 7      7     g      7
# 8      8     h      6
# 9      9     i     10
# 10    10     j      7
# 11    11     k      8

# %%
a["dist"]=("vij","viz","east","west","hyd","bza","krishna","nellore","guntur","kadapa","hyd")
a
# Out:
#     S.NO name  marks     dist
# 0      1    a     10      vij
# 1      2    b      9      viz
# 2      3    c      8     east
# 3      4    d      8     west
# 4      5    e      9      hyd
# 5      6    f     10      bza
# 6      7    g      7  krishna
# 7      8    h      6  nellore
# 8      9    i     10   guntur
# 9     10    j      7   kadapa
# 10    11    k      8      hyd

# %%
a.rename({"dist":"city"},axis=1)
# Out:
#     roll_number class  parent     city
# 0             1     a      10      vij
# 1             2     b       9      viz
# 2             3     c       8     east
# 3             4     d       8     west
# 4             5     e       9      hyd
# 5             6     f      10      bza
# 6             7     g       7  krishna
# 7             8     h       6  nellore
# 8             9     i      10   guntur
# 9            10     j       7   kadapa
# 10           11     k       8      hyd

# %%
a.rename(columns=str.upper)
# Out:
#     S.NO NAME  MARKS     DIST
# 0      1    a     10      vij
# 1      2    b      9      viz
# 2      3    c      8     east
# 3      4    d      8     west
# 4      5    e      9      hyd
# 5      6    f     10      bza
# 6      7    g      7  krishna
# 7      8    h      6  nellore
# 8      9    i     10   guntur
# 9     10    j      7   kadapa
# 10    11    k      8      hyd

# %%
a.columns=["roll_number","class","parent","city"]
a
# Out:
#     roll_number class  parent     city
# 0             1     a      10      vij
# 1             2     b       9      viz
# 2             3     c       8     east
# 3             4     d       8     west
# 4             5     e       9      hyd
# 5             6     f      10      bza
# 6             7     g       7  krishna
# 7             8     h       6  nellore
# 8             9     i      10   guntur
# 9            10     j       7   kadapa
# 10           11     k       8      hyd

# %%
d=a.parent.astype('float')
d
# Out:
# 0     10.0
# 1      9.0
# 2      8.0
# 3      8.0
# 4      9.0
# 5     10.0
# 6      7.0
# 7      6.0
# 8     10.0
# 9      7.0
# 10     8.0
# Name: parent, dtype: float64
