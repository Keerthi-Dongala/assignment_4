# %%
import matplotlib.pyplot as plt
import numpy as np
plt.title("line plot")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
xpoints=np.array([0,1,2,3])
ypoints=np.array([10,5,10,18])
plt.plot(xpoints,ypoints)
plt.show()
