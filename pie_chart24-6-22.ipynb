# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,15,50])
co=["hotpink","salmon","blue"]
plt.pie(y,colors=co,labels=["dsp","cd","wt"])
plt.legend()
plt.show()

# %%
#plot1
x=np.array([0,1,2,3])
y=np.array([10,8,30,4])
plt.subplot(1,2,1)
plt.plot(x,y)
#plot2
x=np.array([0,1,2,3])
y=np.array([10,18,12,4])
plt.subplot(1,2,2)
plt.plot(y)
