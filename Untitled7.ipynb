# %%
#multilinear regression
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
x=[[0,1],[5,1],[15,2],[25,5],[35,11],[45,15],[55,34],[60,35]]
y=[4,5,20,14,32,22,38,43]
x,y=np.array(x),np.array(y)
model=LinearRegression().fit(x,y)
r_sq=model.score(x,y)
print(f"coef of determination:{r_sq}")
print(f"intercept:{model.intercept_}")
print(f"coef:{model.coef_}")
y_pred=model.predict(x)
print(f"predict response:{y_pred}")
y_pred=model.intercept_+np.sum(model.coef_*x,axis=1)
print(f"preicted rsponse:{y_pred}")
x_new=np.arange(10).reshape((-1,2))
y_new=model.predict(x_new)
# Out:
# coef of determination:0.8615939258756776
# intercept:5.522579275198183
# coef:[0.44706965 0.25502548]
# predict response:[ 5.77760476  8.012953   12.73867497 17.9744479  23.97529728 29.4660957
#  38.78227633 41.27265006]
# preicted rsponse:[ 5.77760476  8.012953   12.73867497 17.9744479  23.97529728 29.4660957
#  38.78227633 41.27265006]

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y_pred)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(x_new,y_new)
plt.show()
