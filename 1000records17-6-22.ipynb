# %%
import pandas as pd
df=pd.read_csv("1000records.csv")
df
# Out:
#      Age Attrition     BusinessTravel  DailyRate              Department  \
# 0     31        No  Travel_Frequently        836                 Support
# 1     43       Yes         Non-Travel       1071         Human Resources
# 2     25       Yes         Non-Travel       1374  Research & Development
# 3     29        No  Travel_Frequently       1415                 Support
# 4     20       Yes      Travel_Rarely       1076         Human Resources
# ..   ...       ...                ...        ...                     ...
# 995   49        No         Non-Travel       1465                 Support
# 996   24       Yes  Travel_Frequently        387                   Sales
# 997   45       Yes      Travel_Rarely       1304                Software
# 998   39        No         Non-Travel        217                Hardware
# 999   19       Yes  Travel_Frequently       1447                Hardware
#
#      DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Age Attrition     BusinessTravel  DailyRate              Department  \
# 0     31        No  Travel_Frequently        836                 Support
# 1     43       Yes         Non-Travel       1071         Human Resources
# 2     25       Yes         Non-Travel       1374  Research & Development
# 3     29        No  Travel_Frequently       1415                 Support
# 4     20       Yes      Travel_Rarely       1076         Human Resources
# ..   ...       ...                ...        ...                     ...
# 995   49        No         Non-Travel       1465                 Support
# 996   24       Yes  Travel_Frequently        387                   Sales
# 997   45       Yes      Travel_Rarely       1304                Software
# 998   39        No         Non-Travel        217                Hardware
# 999   19       Yes  Travel_Frequently       1447                Hardware
#
# ...

# %%
df.tail()
# Out:
#      Age Attrition     BusinessTravel  DailyRate Department  DistanceFromHome  \
# 995   49        No         Non-Travel       1465    Support                28
# 996   24       Yes  Travel_Frequently        387      Sales                45
# 997   45       Yes      Travel_Rarely       1304   Software                 7
# 998   39        No         Non-Travel        217   Hardware                39
# 999   19       Yes  Travel_Frequently       1447   Hardware                 6
#
#      Education    EducationField  EmployeeCount  EmployeeNumber  ...  \
# 995          3   Human Resources              1             996  ...
# 996          3  Technical Degree              1             997  ...
# 997          5             Other              1             998  ...
# 998          4   Human Resources              1             999  ...
# 999          5     Life Sciences              1            1000  ...
#
#      RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   31        No  Travel_Frequently        836                 Support
# 1   43       Yes         Non-Travel       1071         Human Resources
# 2   25       Yes         Non-Travel       1374  Research & Development
# 3   29        No  Travel_Frequently       1415                 Support
# 4   20       Yes      Travel_Rarely       1076         Human Resources
#
#    DistanceFromHome  Education    EducationField  EmployeeCount  \
# 0                16          5             Other              1
# 1                14          3             Other              1
# 2                 3          5     Life Sciences              1
# 3                30          2  Technical Degree              1
# 4                19          3           Medical              1
#
#    EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0               1  ...                         3            80
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info
# Out:
# <bound method DataFrame.info of      Age Attrition     BusinessTravel  DailyRate              Department  \
# 0     31        No  Travel_Frequently        836                 Support
# 1     43       Yes         Non-Travel       1071         Human Resources
# 2     25       Yes         Non-Travel       1374  Research & Development
# 3     29        No  Travel_Frequently       1415                 Support
# 4     20       Yes      Travel_Rarely       1076         Human Resources
# ..   ...       ...                ...        ...                     ...
# 995   49        No         Non-Travel       1465                 Support
# 996   24       Yes  Travel_Frequently        387                   Sales
# 997   45       Yes      Travel_Rarely       1304                Software
# 998   39        No         Non-Travel        217                Hardware
# 999   19       Yes  Travel_Frequently       1447                Hardware
#
# ...

# %%
print(df.loc[5])
# Out:
# Age                                        46
# Attrition                                 Yes
# BusinessTravel              Travel_Frequently
# DailyRate                                1176
# Department                    Human Resources
# DistanceFromHome                           23
# Education                                   2
# EducationField                      Marketing
# EmployeeCount                               1
# EmployeeNumber                              6
# EnvironmentSatisfaction                     1
# Gender                                   Male
# HourlyRate                                 48
# JobInvolvement                              1
# JobLevel                                    1
# JobRole                             Developer
# JobSatisfaction                             1
# MaritalStatus                        Divorced
# MonthlyIncome                           16602
# MonthlyRate                             16602
# ...

# %%
print(df.loc[df["Age"]<25])
# Out:
#      Age Attrition     BusinessTravel  DailyRate       Department  \
# 4     20       Yes      Travel_Rarely       1076  Human Resources
# 7     18        No      Travel_Rarely        319  Human Resources
# 13    19       Yes  Travel_Frequently        894  Human Resources
# 24    19        No         Non-Travel        561            Sales
# 25    19       Yes      Travel_Rarely       1219            Sales
# ..   ...       ...                ...        ...              ...
# 987   24       Yes         Non-Travel        440            Sales
# 991   20        No      Travel_Rarely        530  Human Resources
# 993   20       Yes  Travel_Frequently        901  Human Resources
# 996   24       Yes  Travel_Frequently        387            Sales
# 999   19       Yes  Travel_Frequently       1447         Hardware
#
#      DistanceFromHome  Education    EducationField  EmployeeCount  \
# 4                  19          3           Medical              1
# ...

# %%
df.loc[1]
# Out:
# Age                                      43
# Attrition                               Yes
# BusinessTravel                   Non-Travel
# DailyRate                              1071
# Department                  Human Resources
# DistanceFromHome                         14
# Education                                 3
# EducationField                        Other
# EmployeeCount                             1
# EmployeeNumber                            2
# EnvironmentSatisfaction                   3
# Gender                               Female
# HourlyRate                              156
# JobInvolvement                            1
# JobLevel                                  5
# JobRole                     Human Resources
# JobSatisfaction                           4
# MaritalStatus                       Married
# MonthlyIncome                         20424
# MonthlyRate                          326784
# NumCompaniesWorked                        2
# ...

# %%
newdf=df[(df.Age<19)&(df.Education>3)]
newdf
# Out:
#      Age Attrition     BusinessTravel  DailyRate              Department  \
# 7     18        No      Travel_Rarely        319         Human Resources
# 37    18        No  Travel_Frequently       1382                 Support
# 351   18       Yes      Travel_Rarely       1462  Research & Development
# 357   18       Yes         Non-Travel        990                Hardware
# 364   18        No  Travel_Frequently        963                   Sales
# 370   18       Yes  Travel_Frequently        670         Human Resources
# 731   18        No         Non-Travel        247  Research & Development
# 970   18       Yes  Travel_Frequently       1487                   Sales
#
#      DistanceFromHome  Education   EducationField  EmployeeCount  \
# 7                  28          4    Life Sciences              1
# 37                 16          5  Human Resources              1
# 351                46          4        Marketing              1
# ...

# %%
df.to_excel("1000records.xlsx")
df.read_excel("1000records.xlsx")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [23], in <cell line: 2>()
#       1 df.to_excel("1000records.xlsx")
# ----> 2 df.read_excel("1000records.xlsx")
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'read_excel'
